# %% [markdown]
# ### Find Wikipedia Article

# %%
import os
from utils.utils_wiki import get_wikipedia_article, save_wikipedia_page, extract_sections

person_name = "Albrecht Duerer"

# person_name = "Ida Pfeiffer" # To test for any name on the go ...

wikipedia_title = person_name

if not os.path.exists("data/wikipedia"): os.makedirs("data/wikipedia")
if not os.path.exists("data/json"): os.makedirs("data/json")

wiki_page = get_wikipedia_article(person_name)
if wiki_page:
    print(f"Found a Page: {wiki_page.title}")
    wikipedia_title = wiki_page.title
    text = wiki_page.content
    text_filename = f"data/wikipedia/{wikipedia_title.replace(' ', '_').lower()}.txt"
    json_nlp_filename = f"data/json/{wikipedia_title.replace(' ', '_').lower()}.json"
    save_wikipedia_page(wiki_page, text_filename, include_metadata=True, include_sections=True)
else:
    print(f"Query Failed! Couldn't find {person_name}")
# Out:
# Options: {'Erasmus', 'Albrecht Dürer', 'Deutsche Schule Sevilla'}
# Ordered Options Compund Metric: [RankedArticle(wikipage_title='Albrecht Dürer', queried_name='Albrecht Duerer', lev_similarity=0.896551724137931, token_overlap=0.5, dates_confidence=-1)]
#
# Retrieving page for Albrecht Dürer
# Wiki Life Data = (1471 - 1528)
# Page Chosen! Confidence Score = 1
# Found a Page: Albrecht Dürer

# %% [markdown]
# ### Clean & Pre-process Text

# %%
import utils.nlp_common as unlp
import spacy
from spacy import __version__ as spacy_version


text_filename = f"data/wikipedia/{wikipedia_title.replace(' ', '_').lower()}.txt"
text_clean_filename = f"data/wikipedia/{wikipedia_title.replace(' ', '_').lower()}.clean.txt"
json_nlp_filename = f"data/json/{wikipedia_title.replace(' ', '_').lower()}.json"

with open(text_filename) as f:
    text = f.read()
    text = unlp.preprocess_and_clean_text(text)
    nlp_dict, is_from_file = unlp.create_nlp_template(text, filepath=json_nlp_filename)

# NLP Basic processing using SpaCy (Only if file did not exist already)
if not is_from_file:
    spacy_model = "en_core_web_lg"
    nlp = spacy.load(spacy_model)
    spacy_dict = unlp.run_spacy(text, nlp)
    sentences = spacy_dict['sentences']
    token_objs = spacy_dict['token_objs']
    nlp_dict['tokenization'] = {f'spacy_{spacy_model}_{spacy_version}': spacy_dict['tokens']}
    nlp_dict['morpho_syntax'] = {f'spacy_{spacy_model}_{spacy_version}': unlp.add_morphosyntax(spacy_dict['token_objs'])}
else:
    sentences, token_objs = [], []
    flair_versions = [v for v in nlp_dict['morpho_syntax'].keys() if 'flair_' in v]
    if len(flair_versions)>0:
        print("Taking sentences as defined by FLAIR (for compatibility reasons)")
        for sent_ix, sent_obj in enumerate(nlp_dict['morpho_syntax'][flair_versions[0]]):
            if len(sent_obj['text']) > 0:
                sentences.append(sent_obj['text'])
                for tok in sent_obj['words']:
                    token_objs.append({'sent_id': sent_ix, 'text': tok['FORM'], 'lemma': tok['FORM'], 
                                    'start_char': tok['MISC']['StartChar'], 'end_char': tok['MISC']['EndChar'], 'space_after': tok['MISC']['SpaceAfter']})

with open(text_clean_filename, "w") as f: f.write(text)
print(len(text), text[:100])
print(nlp_dict.keys())
print(f"Loaded from Flair file: {is_from_file}")
# Out:
# Taking sentences as defined by FLAIR (for compatibility reasons)
# 33155 Albrecht Dürer (; German: [ˈʔalbʁɛçt ˈdyːʁɐ]; 21 May 1471 – 6 April 1528), sometimes spelled in Engl
# dict_keys(['text', 'tokenization', 'morpho_syntax', 'entities', 'time_expressions', 'semantic_roles', 'coreference', 'relations', 'linked_entities', 'frames'])
# True

# %% [markdown]
# ### Find Semantic Roles

# %%
from utils.nlp_allen import add_json_srl_allennlp
from allennlp.predictors import Predictor

srl_predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz")
nlp_dict['semantic_roles'] += add_json_srl_allennlp(sentences, srl_predictor, token_objs)
# Out:
# 2023-08-22 14:13:08,332 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2023-08-22 14:13:09,163 - INFO - cached_path - cache of https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz is up-to-date
# 2023-08-22 14:13:09,164 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz from cache at /Users/daza/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3
# 2023-08-22 14:13:09,165 - INFO - allennlp.models.archival - extracting archive file /Users/daza/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3 to temp dir /var/folders/dx/h319cjln6sz2cjsd0t05zgjr0000gn/T/tmplbe8fat0
# 2023-08-22 14:13:12,476 - INFO - allennlp.common.params - dataset_reader.type = srl
# 2023-08-22 14:13:12,477 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# 2023-08-22 14:13:12,477 - INFO - allennlp.common.params - dataset_reader.manual_distributed_sharding = False
# 2023-08-22 14:13:12,478 - INFO - allennlp.common.params - dataset_reader.manual_multiprocess_sharding = False
# 2023-08-22 14:13:12,478 - INFO - allennlp.common.params - dataset_reader.token_indexers = None
# 2023-08-22 14:13:12,479 - INFO - allennlp.common.params - dataset_reader.domain_identifier = None
# 2023-08-22 14:13:12,479 - INFO - allennlp.common.params - dataset_reader.bert_model_name = bert-base-uncased
# 2023-08-22 14:13:32,219 - INFO - allennlp.common.params - dataset_reader.type = srl
# 2023-08-22 14:13:32,220 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# 2023-08-22 14:13:32,221 - INFO - allennlp.common.params - dataset_reader.manual_distributed_sharding = False
# 2023-08-22 14:13:32,222 - INFO - allennlp.common.params - dataset_reader.manual_multiprocess_sharding = False
# 2023-08-22 14:13:32,222 - INFO - allennlp.common.params - dataset_reader.token_indexers = None
# 2023-08-22 14:13:32,223 - INFO - allennlp.common.params - dataset_reader.domain_identifier = None
# 2023-08-22 14:13:32,224 - INFO - allennlp.common.params - dataset_reader.bert_model_name = bert-base-uncased
# 2023-08-22 14:13:37,687 - INFO - allennlp.common.params - type = from_instances
# 2023-08-22 14:13:37,688 - INFO - allennlp.data.vocabulary - Loading token dictionary from /var/folders/dx/h319cjln6sz2cjsd0t05zgjr0000gn/T/tmplbe8fat0/vocabulary.
# 2023-08-22 14:13:37,690 - INFO - allennlp.common.params - model.type = srl_bert
# 2023-08-22 14:13:37,691 - INFO - allennlp.common.params - model.regularizer = None
# 2023-08-22 14:13:37,692 - INFO - allennlp.common.params - model.ddp_accelerator = None
# 2023-08-22 14:13:37,693 - INFO - allennlp.common.params - model.bert_model = bert-base-uncased
# 2023-08-22 14:13:37,693 - INFO - allennlp.common.params - model.embedding_dropout = 0.1
# 2023-08-22 14:13:37,694 - INFO - allennlp.common.params - model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7fbc0739f990>
# 2023-08-22 14:13:37,694 - INFO - allennlp.common.params - model.label_smoothing = None
# 2023-08-22 14:13:37,695 - INFO - allennlp.common.params - model.ignore_span_metric = False
# 2023-08-22 14:13:37,695 - INFO - allennlp.common.params - model.srl_eval_path = /Users/daza/anaconda3/envs/allennlp_env/lib/python3.7/site-packages/allennlp_models/structured_prediction/tools/srl-eval.pl
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-08-22 14:13:40,766 - INFO - allennlp.nn.initializers - Initializing parameters
# 2023-08-22 14:13:40,768 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2023-08-22 14:13:40,769 - INFO - allennlp.nn.initializers -    bert_model.embeddings.LayerNorm.bias
# 2023-08-22 14:13:40,769 - INFO - allennlp.nn.initializers -    bert_model.embeddings.LayerNorm.weight
# 2023-08-22 14:13:40,770 - INFO - allennlp.nn.initializers -    bert_model.embeddings.position_embeddings.weight
# 2023-08-22 14:13:40,770 - INFO - allennlp.nn.initializers -    bert_model.embeddings.token_type_embeddings.weight
# 2023-08-22 14:13:40,771 - INFO - allennlp.nn.initializers -    bert_model.embeddings.word_embeddings.weight
# 2023-08-22 14:13:40,772 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.output.LayerNorm.bias
# 2023-08-22 14:13:40,772 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.output.LayerNorm.weight
# 2023-08-22 14:13:40,773 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.output.dense.bias
# 2023-08-22 14:13:40,773 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.output.dense.weight
# 2023-08-22 14:13:40,774 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.key.bias
# 2023-08-22 14:13:40,775 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.key.weight
# 2023-08-22 14:13:40,775 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.query.bias
# 2023-08-22 14:13:40,776 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.query.weight
# 2023-08-22 14:13:40,776 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.value.bias
# 2023-08-22 14:13:40,777 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.value.weight
# 2023-08-22 14:13:40,777 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.intermediate.dense.bias
# 2023-08-22 14:13:40,778 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.intermediate.dense.weight
# 2023-08-22 14:13:40,778 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.output.LayerNorm.bias
# 2023-08-22 14:13:40,779 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.output.LayerNorm.weight
# 2023-08-22 14:13:40,779 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.output.dense.bias
# 2023-08-22 14:13:40,780 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.output.dense.weight
# 2023-08-22 14:13:40,780 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.output.LayerNorm.bias
# 
- INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.query.weight
# 2023-08-22 14:13:40,866 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.value.bias
# 2023-08-22 14:13:40,882 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.value.weight
# 2023-08-22 14:13:40,893 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.intermediate.dense.bias
# 2023-08-22 14:13:40,901 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.intermediate.dense.weight
# 2023-08-22 14:13:40,901 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.LayerNorm.bias
# 2023-08-22 14:13:40,902 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.LayerNorm.weight
# 2023-08-22 14:13:40,903 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.dense.bias
# 2023-08-22 14:13:40,904 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.dense.weight
# 2023-08-22 14:13:40,904 - INFO - allennlp.nn.initializers -    bert_model.pooler.dense.bias
# 2023-08-22 14:13:40,905 - INFO - allennlp.nn.initializers -    bert_model.pooler.dense.weight
# 2023-08-22 14:13:40,906 - INFO - allennlp.nn.initializers -    tag_projection_layer.bias
# 2023-08-22 14:13:40,906 - INFO - allennlp.nn.initializers -    tag_projection_layer.weight
# 2023-08-22 14:13:41,603 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /var/folders/dx/h319cjln6sz2cjsd0t05zgjr0000gn/T/tmplbe8fat0

# %% [markdown]
# ### Find Named Entities (AllenNLP)

# %%
from utils.nlp_allen import add_json_ner_allennlp

ner_predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/ner-elmo.2021-02-12.tar.gz")
nlp_dict['entities'] += add_json_ner_allennlp(sentences, ner_predictor, token_objs)

# %% [markdown]
# ### Find Coreferences (AllenNLP)

# %%
from utils.nlp_allen import add_json_coref_allennlp

coref_predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2021.03.10.tar.gz")
nlp_dict['coreference'] = add_json_coref_allennlp(sentences, coref_predictor)
# Out:
# 2023-08-22 14:17:50,741 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2023-08-22 14:17:51,613 - INFO - cached_path - cache of https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2021.03.10.tar.gz is up-to-date
# 2023-08-22 14:17:51,614 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2021.03.10.tar.gz from cache at /Users/daza/.allennlp/cache/038f918d294bd1a45e3709dfb22af5277b0be8677f750a85748c39979ce0e549.b897bfe76a04a5f70d6e88762a4d819b4b8b90e45b31b8314e0a6a9630d3f213
# 2023-08-22 14:17:51,615 - INFO - allennlp.models.archival - extracting archive file /Users/daza/.allennlp/cache/038f918d294bd1a45e3709dfb22af5277b0be8677f750a85748c39979ce0e549.b897bfe76a04a5f70d6e88762a4d819b4b8b90e45b31b8314e0a6a9630d3f213 to temp dir /var/folders/dx/h319cjln6sz2cjsd0t05zgjr0000gn/T/tmp385d2l24
# 2023-08-22 14:18:03,634 - INFO - allennlp.common.params - dataset_reader.type = coref
# 2023-08-22 14:18:03,645 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# 2023-08-22 14:18:03,646 - INFO - allennlp.common.params - dataset_reader.manual_distributed_sharding = False
# 2023-08-22 14:18:03,647 - INFO - allennlp.common.params - dataset_reader.manual_multiprocess_sharding = False
# 2023-08-22 14:18:03,647 - INFO - allennlp.common.params - dataset_reader.max_span_width = 30
# 2023-08-22 14:18:03,650 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2023-08-22 14:18:03,653 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2023-08-22 14:18:03,653 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.model_name = SpanBERT/spanbert-large-cased
# 2023-08-22 14:18:03,654 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.namespace = tags
# 2023-08-22 14:18:03,655 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.max_length = 512
# 2023-08-22 14:18:03,658 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.tokenizer_kwargs = None
# 2023-08-22 14:18:19,612 - INFO - allennlp.common.params - dataset_reader.wordpiece_modeling_tokenizer = None
# 2023-08-22 14:18:19,613 - INFO - allennlp.common.params - dataset_reader.max_sentences = 110
# 2023-08-22 14:18:19,613 - INFO - allennlp.common.params - dataset_reader.remove_singleton_clusters = False
# 2023-08-22 14:18:19,617 - INFO - allennlp.common.params - validation_dataset_reader.type = coref
# 2023-08-22 14:18:19,618 - INFO - allennlp.common.params - validation_dataset_reader.max_instances = None
# 2023-08-22 14:18:19,618 - INFO - allennlp.common.params - validation_dataset_reader.manual_distributed_sharding = False
# 2023-08-22 14:18:19,619 - INFO - allennlp.common.params - validation_dataset_reader.manual_multiprocess_sharding = False
# 2023-08-22 14:18:19,619 - INFO - allennlp.common.params - validation_dataset_reader.max_span_width = 30
# 2023-08-22 14:18:19,620 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2023-08-22 14:18:19,621 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2023-08-22 14:18:19,622 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.model_name = SpanBERT/spanbert-large-cased
# 2023-08-22 14:18:19,622 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.namespace = tags
# 2023-08-22 14:18:19,623 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.max_length = 512
# 2023-08-22 14:18:19,623 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.tokenizer_kwargs = None
# 2023-08-22 14:18:19,625 - INFO - allennlp.common.params - validation_dataset_reader.wordpiece_modeling_tokenizer = None
# 2023-08-22 14:18:19,626 - INFO - allennlp.common.params - validation_dataset_reader.max_sentences = None
# 2023-08-22 14:18:19,627 - INFO - allennlp.common.params - validation_dataset_reader.remove_singleton_clusters = False
# 2023-08-22 14:18:19,629 - INFO - allennlp.common.params - type = from_instances
# 2023-08-22 14:18:19,630 - INFO - allennlp.data.vocabulary - Loading token dictionary from /var/folders/dx/h319cjln6sz2cjsd0t05zgjr0000gn/T/tmp385d2l24/vocabulary.
# 2023-08-22 14:18:19,633 - INFO - allennlp.common.params - model.type = coref
# 2023-08-22 14:18:19,637 - INFO - allennlp.common.params - model.regularizer = None
# 2023-08-22 14:18:19,639 - INFO - allennlp.common.params - model.ddp_accelerator = None
# 2023-08-22 14:18:19,640 - INFO - allennlp.common.params - model.text_field_embedder.type = basic
# 2023-08-22 14:18:19,642 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = pretrained_transformer_mismatched
# 2023-08-22 14:18:19,642 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.model_name = SpanBERT/spanbert-large-cased
# 2023-08-22 14:18:19,643 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.max_length = 512
# 2023-08-22 14:18:19,644 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.train_parameters = True
# 2023-08-22 14:18:19,644 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.last_layer_only = True
# 2023-08-22 14:18:19,645 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.override_weights_file = None
# 2023-08-22 14:18:19,645 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.override_weights_strip_prefix = None
# 2023-08-22 14:18:19,646 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.load_weights = True
# 2023-08-22 14:18:19,646 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.gradient_checkpointing = None
# 2023-08-22 14:18:19,647 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.tokenizer_kwargs = None
# 2023-08-22 14:18:19,647 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.transformer_kwargs = None
# 2023-08-22 14:18:19,648 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.sub_token_mode = avg
# Some weights of BertModel were not initialized from the model checkpoint at SpanBERT/spanbert-large-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2023-08-22 14:18:24,940 - INFO - allennlp.common.params - model.context_layer.type = pass_through
# 2023-08-22 14:18:24,941 - INFO - allennlp.common.params - model.context_layer.input_dim = 1024
# 2023-08-22 14:18:24,941 - INFO - allennlp.common.params - model.mention_feedforward.input_dim = 3092
# 2023-08-22 14:18:24,942 - INFO - allennlp.common.params - model.mention_feedforward.num_layers = 2
# 2023-08-22 14:18:24,943 - INFO - allennlp.common.params - model.mention_feedforward.hidden_dims = 1500
# 2023-08-22 14:18:24,943 - INFO - allennlp.common.params - model.mention_feedforward.activations = relu
# 2023-08-22 14:18:24,944 - INFO - allennlp.common.params - type = relu
# 2023-08-22 14:18:24,944 - INFO - allennlp.common.params - model.mention_feedforward.dropout = 0.3
# 2023-08-22 14:18:24,986 - INFO - allennlp.common.params - model.antecedent_feedforward.input_dim = 9296
# 2023-08-22 14:18:24,986 - INFO - allennlp.common.params - model.antecedent_feedforward.num_layers = 2
# 2023-08-22 14:18:24,987 - INFO - allennlp.common.params - model.antecedent_feedforward.hidden_dims = 1500
# 2023-08-22 14:18:24,987 - INFO - allennlp.common.params - model.antecedent_feedforward.activations = relu
# 2023-08-22 14:18:24,988 - INFO - allennlp.common.params - type = relu
# 2023-08-22 14:18:24,989 - INFO - allennlp.common.params - model.antecedent_feedforward.dropout = 0.3
# 2023-08-22 14:18:25,085 - INFO - allennlp.common.params - model.feature_size = 20
# 2023-08-22 14:18:25,086 - INFO - allennlp.common.params - model.max_span_width = 30
# 2023-08-22 14:18:25,086 - INFO - allennlp.common.params - model.spans_per_word = 0.4
# 2023-08-22 14:18:25,087 - INFO - allennlp.common.params - model.max_antecedents = 50
# 2023-08-22 14:18:25,087 - INFO - allennlp.common.params - model.coarse_to_fine = True
# 2023-08-22 14:18:25,088 - INFO - allennlp.common.params - model.inference_order = 2
# 2023-08-22 14:18:25,089 - INFO - allennlp.common.params - model.lexical_dropout = 0.2
# 2023-08-22 14:18:25,089 - INFO - allennlp.common.params - model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7fbc06f7a750>
# 2023-08-22 14:18:25,152 - INFO - allennlp.nn.initializers - Initializing parameters
# 2023-08-22 14:18:25,155 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2023-08-22 14:18:25,156 - INFO - allennlp.nn.initializers -    _antecedent_feedforward._module._linear_layers.0.bias
# 2023-08-22 14:18:25,156 - INFO - allennlp.nn.initializers -    _antecedent_feedforward._module._linear_layers.0.weight
# 2023-08-22 14:18:25,157 - INFO - allennlp.nn.initializers -    _antecedent_feedforward._module._linear_layers.1.bias
# 2023-08-22 14:18:25,157 - INFO - allennlp.nn.initializers -    _antecedent_feedforward._module._linear_layers.1.weight
# 2023-08-22 14:18:25,158 - INFO - allennlp.nn.initializers -    _antecedent_scorer._module.bias
# 2023-08-22 14:18:25,158 - INFO - allennlp.nn.initializers -    _antecedent_scorer._module.weight
# 2023-08-22 14:18:25,159 - INFO - allennlp.nn.initializers -    _attentive_span_extractor._global_attention._module.bias
# 2023-08-22 14:18:25,159 - INFO - allennlp.nn.initializers -    _attentive_span_extractor._global_attention._module.weight
# 2023-08-22 14:18:25,160 - INFO - allennlp.nn.initializers -    _coarse2fine_scorer.bias
# 2023-08-22 14:18:25,160 - INFO - allennlp.nn.initializers -    _coarse2fine_scorer.weight
# 2023-08-22 14:18:25,160 - INFO - allennlp.nn.initializers -    _distance_embedding.weight
# 2023-08-22 14:18:25,161 - INFO - allennlp.nn.initializers -    _endpoint_span_extractor._span_width_embedding.weight
# 2023-08-22 14:18:25,161 - INFO - allennlp.nn.initializers -    _mention_feedforward._module._linear_layers.0.bias
# 2023-08-22 14:18:25,162 - INFO - allennlp.nn.initializers -    _mention_feedforward._module._linear_layers.0.weight
# 2023-08-22 14:18:25,162 - INFO - allennlp.nn.initializers -    _mention_feedforward._module._linear_layers.1.bias
# 2023-08-22 14:18:25,162 - INFO - allennlp.nn.initializers -    _mention_feedforward._module._linear_layers.1.weight
# 2023-08-22 14:18:25,163 - INFO - allennlp.nn.initializers -    _mention_scorer._module.bias
# 2023-08-22 14:18:25,163 - INFO - allennlp.nn.initializers -    _mention_scorer._module.weight
# 2023-08-22 14:18:25,163 - INFO - allennlp.nn.initializers -    _span_updating_gated_sum._gate.bias
# 2023-08-22 14:18:25,164 - INFO - allennlp.nn.initializers -    _span_updating_gated_sum._gate.weight
# 2023-08-22 14:18:25,164 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.LayerNorm.bias
# 2023-08-22 14:18:25,165 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.LayerNorm.weight
# 2023-08-22 14:18:25,165 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.position_embeddings.weight
# 2023-08-22 14:18:25,166 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.token_type_embeddings.weight
# 2023-08-22 14:18:25,166 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.word_embeddings.weight
# 2023-08-22 14:18:25,167 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.LayerNorm.bias
# 2023-08-22 14:18:25,167 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.LayerNorm.weight
# 2023-08-22 14:18:25,167 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.dense.bias
# 2023-08-22 14:18:25,168 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.dense.weight
# 2023-08-22 14:18:25,168 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.key.bias
# 2023-08-22 14:18:25,169 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.key.weight
# 2023-08-22 14:18:25,169 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.query.bias
# 2023-08-22 14:18:25,170 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.query.weight
# 2023-08-22 14:18:25,170 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.value.bias
# 2023-08-22 14:18:25,171 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.value.weight
# 2023-08-22 14:18:25,171 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.intermediate.dense.bias
# 2023-08-22 14:18:25,171 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.intermediate.dense.weight
# 2023-08-22 14:18:25,172 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.LayerNorm.bias
# 2023-08-22 14:18:25,172 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.LayerNorm.weight
# 2023-08-22 14:18:25,173 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.dense.bias
# 2023-08-22 14:18:25,173 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.dense.weight
# 2023-08-22 14:18:25,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.LayerNorm.bias
# 2023-08-22 14:18:25,174 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.LayerNorm.weight
# 2023-08-22 14:18:25,175 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.dense.bias
# 2023-08-22 14:18:25,175 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.dense.weight
# 2023-08-22 14:18:25,175 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.key.bias
# 2023-08-22 14:18:25,176 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.key.weight
# 2023-08-22 14:18:25,176 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.query.bias
# 2023-08-22 14:18:25,177 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.query.weight
# 2023-08-22 14:18:25,177 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.value.bias
# 2023-08-22 14:18:25,178 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.value.weight
# 2023-08-22 14:18:25,178 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.intermediate.dense.bias
# 
418 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.bias
# 2023-08-22 14:18:25,418 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.weight
# 2023-08-22 14:18:25,419 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.bias
# 2023-08-22 14:18:25,419 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.weight
# 2023-08-22 14:18:25,419 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.bias
# 2023-08-22 14:18:25,420 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.weight
# 2023-08-22 14:18:25,420 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.bias
# 2023-08-22 14:18:25,421 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.weight
# 2023-08-22 14:18:25,421 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.bias
# 2023-08-22 14:18:25,422 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.weight
# 2023-08-22 14:18:25,422 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.bias
# 2023-08-22 14:18:25,423 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.weight
# 2023-08-22 14:18:25,423 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.bias
# 2023-08-22 14:18:25,424 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.weight
# 2023-08-22 14:18:25,424 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2023-08-22 14:18:25,425 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2023-08-22 14:18:25,425 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.bias
# 2023-08-22 14:18:25,426 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.weight
# 2023-08-22 14:18:25,426 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.bias
# 2023-08-22 14:18:25,426 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.weight
# 2023-08-22 14:18:25,427 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.bias
# 2023-08-22 14:18:25,427 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.weight
# 2023-08-22 14:18:25,428 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.bias
# 2023-08-22 14:18:25,428 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.weight
# 2023-08-22 14:18:25,429 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2023-08-22 14:18:25,429 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2023-08-22 14:18:25,429 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2023-08-22 14:18:25,430 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2023-08-22 14:18:25,430 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.bias
# 2023-08-22 14:18:25,431 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.weight
# 2023-08-22 14:18:25,431 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.bias
# 2023-08-22 14:18:25,432 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.weight
# 2023-08-22 14:18:25,445 - INFO - allennlp.modules.token_embedders.embedding - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2023-08-22 14:18:25,445 - INFO - allennlp.modules.token_embedders.embedding - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2023-08-22 14:18:31,967 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /var/folders/dx/h319cjln6sz2cjsd0t05zgjr0000gn/T/tmp385d2l24
# /Users/daza/anaconda3/envs/allennlp_env/lib/python3.7/site-packages/allennlp/modules/token_embedders/pretrained_transformer_embedder.py:385: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   num_effective_segments = (seq_lengths + self._max_length - 1) // self._max_length

# %% [markdown]
# ### Merge Predicate Senses with SRL

# %%
from utils.nlp_common import merge_frames_srl

merged = merge_frames_srl(nlp_dict["semantic_roles"], nlp_dict["frames"])
nlp_dict["semantic_roles"] = merged
if 'frames' in nlp_dict: del nlp_dict['frames']
# Out:
# [('match', 585), ('non_match', 32), ('fuzzy_match', 2)]
# -----------------------------------

# %% [markdown]
# ### Find Time Expressions (HeidelTime)

# %%
from python_heideltime import Heideltime
from utils.nlp_heideltime import add_json_heideltime
heideltime_parser = Heideltime()
heideltime_parser.set_language('ENGLISH')
heideltime_parser.set_document_type('NARRATIVES')

nlp_dict['time_expressions'] = add_json_heideltime(text, heideltime_parser)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# ### Save File

# %%
import json

print(len(nlp_dict["coreference"]))

intavia_dict = {
            'status': '200',
            'data': nlp_dict
        }
print(json_nlp_filename)
json.dump(intavia_dict, open(json_nlp_filename, "w"), indent=2, ensure_ascii=False)
# Out:
# 111
# data/json/albrecht_dürer.json
